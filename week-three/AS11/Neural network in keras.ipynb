# %%
from random import seed
from random import random
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# %%
# generate toy dataset
def generate_data (num_sample_class, dim, num_class):
    X = np.zeros((num_sample_class*num_class,dim)) # data matrix (each row = single example)
    y = np.zeros(num_sample_class*num_class, dtype='uint8') # class labels
    for j in range(num_class):
        ix = range(num_sample_class*j,num_sample_class*(j+1))
        r = np.linspace(0.0,1,num_sample_class) # radius
        t = np.linspace(j*4,(j+1)*4,num_sample_class) + np.random.randn(num_sample_class)*0.2 # theta
        X[ix] = np.c_[r*np.sin(t), r*np.cos(t)]
        y[ix] = j
    # lets visualize the data:
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.Spectral)
    plt.show()
    return X, y

# %%
def model_fit(train_x, train_y, config):
    n_input = config[0]
    n_nodes = config[2]
    n_output = config[1]
    epoch = config[3]
    batch = config[4]
    # Define and Compile
    model = Sequential()
    model.add(Dense(n_nodes, input_dim=n_input, activation='relu'))
    model.add(Dense(n_output, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(train_x, train_y, epochs=epoch, batch_size=batch)
    return model

# predict with the fit model
def model_predict(model, testdata):
    Prediction = model.predict(testdata, verbose=0)
    return Prediction

# Calculate accuracy percentage
def accuracy_metric(actual, predicted):
    correct = 0
    for i in range(len(actual)):
        if actual[i] == predicted[i]:
            correct += 1
    return correct / float(len(actual)) * 100.0

# %%
#example of how to use the ANN model

seed(1)
N = 100 # number of samples per class
D = 2 # dimensionality
K = 3 # number of classes
input_x, target_y =  generate_data (N, D, K)
train_x, test_x, train_y, test_y = train_test_split(input_x, target_y, test_size=0.20, random_state=42)

# encode the labels, 
train_y = to_categorical(train_y, 3)
test_y = to_categorical(test_y, 3)

# %%
config = [2, 3, 20, 100, 1]
neural_network = model_fit(train_x, train_y, config)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 1s 4ms/step - loss: 0.6520 - accuracy: 0.6458
# Epoch 2/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.5960 - accuracy: 0.7069
# Epoch 3/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.5549 - accuracy: 0.7125
# Epoch 4/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.5239 - accuracy: 0.7569
# Epoch 5/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.5014 - accuracy: 0.7792
# Epoch 6/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4847 - accuracy: 0.7944
# Epoch 7/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4727 - accuracy: 0.7917
# Epoch 8/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4632 - accuracy: 0.7778
# Epoch 9/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4556 - accuracy: 0.7736
# Epoch 10/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4494 - accuracy: 0.7778
# Epoch 11/100
# 231/240 [===========================>..] - ETA: 0s - loss: 0.4447 - accuracy: 0.77240/240 [==============================] - 1s 2ms/step - loss: 0.4455 - accuracy: 0.7736
# Epoch 12/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4407 - accuracy: 0.7819
# Epoch 13/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4378 - accuracy: 0.7806
# Epoch 14/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4345 - accuracy: 0.7778
# Epoch 15/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4305 - accuracy: 0.7847
# Epoch 16/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4273 - accuracy: 0.7847
# Epoch 17/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4242 - accuracy: 0.7806
# Epoch 18/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4205 - accuracy: 0.7861
# Epoch 19/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4178 - accuracy: 0.7889
# Epoch 20/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4150 - accuracy: 0.7889
# Epoch 21/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.7944
# Epoch 22/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4086 - accuracy: 0.7875
# Epoch 23/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4050 - accuracy: 0.7958
# Epoch 24/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.4024 - accuracy: 0.8000
# Epoch 25/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3993 - accuracy: 0.8000
# Epoch 26/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3959 - accuracy: 0.8028
# Epoch 27/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3929 - accuracy: 0.8083
# Epoch 28/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3893 - accuracy: 0.8097
# Epoch 29/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3875 - accuracy: 0.8097
# Epoch 30/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3837 - accuracy: 0.8111
# Epoch 31/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3809 - accuracy: 0.8139
# Epoch 32/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3771 - accuracy: 0.8153
# Epoch 33/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3746 - accuracy: 0.8181
# Epoch 34/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3715 - accuracy: 0.8194
# Epoch 35/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3679 - accuracy: 0.8222
# Epoch 36/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3652 - accuracy: 0.8250
# Epoch 37/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3621 - accuracy: 0.8278
# Epoch 38/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3585 - accuracy: 0.8292
# Epoch 39/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3554 - accuracy: 0.8333
# Epoch 40/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3523 - accuracy: 0.8333
# Epoch 41/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3491 - accuracy: 0.8375
# Epoch 42/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3460 - accuracy: 0.8361
# Epoch 43/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3433 - accuracy: 0.8389
# Epoch 44/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3401 - accuracy: 0.8403
# Epoch 45/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3370 - accuracy: 0.8375
# Epoch 46/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8431
# Epoch 47/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8417
# Epoch 48/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3281 - accuracy: 0.8500
# Epoch 49/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3241 - accuracy: 0.8528
# Epoch 50/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3220 - accuracy: 0.8486
# Epoch 51/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3190 - accuracy: 0.8514
# Epoch 52/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.3157 - accuracy: 0.8500
# Epoch 53/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3130 - accuracy: 0.8556
# Epoch 54/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3103 - accuracy: 0.8486
# Epoch 55/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3074 - accuracy: 0.8569
# Epoch 56/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3041 - accuracy: 0.8569
# Epoch 57/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.3012 - accuracy: 0.8583
# Epoch 58/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2986 - accuracy: 0.8597
# Epoch 59/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2969 - accuracy: 0.8639
# Epoch 60/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2937 - accuracy: 0.8653
# Epoch 61/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2904 - accuracy: 0.8681
# Epoch 62/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2879 - accuracy: 0.8681
# Epoch 63/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2847 - accuracy: 0.8736
# Epoch 64/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2820 - accuracy: 0.8764
# Epoch 65/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2794 - accuracy: 0.8750
# Epoch 66/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2777 - accuracy: 0.8778
# Epoch 67/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2739 - accuracy: 0.8847
# Epoch 68/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2714 - accuracy: 0.8833
# Epoch 69/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2687 - accuracy: 0.8833
# Epoch 70/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2656 - accuracy: 0.8889
# Epoch 71/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2632 - accuracy: 0.8917
# Epoch 72/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2602 - accuracy: 0.9028
# Epoch 73/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2577 - accuracy: 0.8875
# Epoch 74/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2554 - accuracy: 0.8917
# Epoch 75/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2526 - accuracy: 0.9069
# Epoch 76/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2501 - accuracy: 0.9014
# Epoch 77/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2472 - accuracy: 0.9000
# Epoch 78/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2449 - accuracy: 0.9111
# Epoch 79/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2424 - accuracy: 0.9111
# Epoch 80/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2398 - accuracy: 0.9028
# Epoch 81/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2376 - accuracy: 0.9083
# Epoch 82/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2350 - accuracy: 0.9125
# Epoch 83/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2329 - accuracy: 0.9167
# Epoch 84/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2304 - accuracy: 0.9153
# Epoch 85/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2274 - accuracy: 0.9181
# Epoch 86/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2250 - accuracy: 0.9167
# Epoch 87/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2227 - accuracy: 0.9236
# Epoch 88/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2203 - accuracy: 0.9236
# Epoch 89/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2180 - accuracy: 0.9236
# Epoch 90/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2153 - accuracy: 0.9292
# Epoch 91/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2128 - accuracy: 0.9333
# Epoch 92/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2108 - accuracy: 0.9306
# Epoch 93/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2086 - accuracy: 0.9361
# Epoch 94/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.2065 - accuracy: 0.9333
# Epoch 95/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2045 - accuracy: 0.9333
# Epoch 96/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.2017 - accuracy: 0.9403
# Epoch 97/100
# 240/240 [==============================] - 1s 2ms/step - loss: 0.1993 - accuracy: 0.9333
# Epoch 98/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.1974 - accuracy: 0.9389
# Epoch 99/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.1943 - accuracy: 0.9403
# Epoch 100/100
# 240/240 [==============================] - 1s 3ms/step - loss: 0.1924 - accuracy: 0.9403

# %%
# Evaluate the model
prediction = model_predict(neural_network, test_x)

PredClass = list()
ActualClass = list()
for row in range(len(test_y)):
    index_maxscore1 = max(range(len(test_y[row])), key=test_y[row].__getitem__)
    ActualClass.append(index_maxscore1)
    index_maxscore2 = max(range(len(prediction[row])), key=prediction[row].__getitem__)
    PredClass.append(index_maxscore2)
    print('Expected=%d, Got=%d' % (index_maxscore1, index_maxscore2))


accuracy = accuracy_metric(PredClass, ActualClass)
accuracy
# Out:
# Expected=2, Got=0
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=1, Got=2
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=1, Got=2
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=0, Got=0
# Expected=1, Got=1
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=0, Got=0
# Expected=0, Got=2
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=1, Got=1
# Expected=1, Got=1
# Expected=2, Got=2
# Expected=0, Got=0
# Expected=2, Got=2
# Expected=2, Got=2
# Expected=0, Got=2
# Expected=0, Got=2
# Expected=1, Got=1
# Expected=0, Got=0
# 90.0
